# %% [markdown]
# #⚠️ 2. Basic Try-Except Block

# %%
# Use try-except to handle errors gracefully

try:
    x = int(input("Enter a number: "))
    print("You entered:", x)
except ValueError:
    print("That was not a valid number!")
# Out:
# Enter a number: san
# That was not a valid number!

# %% [markdown]
# #🔁 3. Try-Except-Else-Finally Structure

# %%
try:
    num = int(input("Enter a number to divide 100: "))
    result = 100 / num
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Invalid input! Not a number.")
else:
    print("Result is:", result)
finally:
    print("Execution complete. This block always runs.")
# Out:
# Enter a number to divide 100: 0
# Cannot divide by zero!
# Execution complete. This block always runs.

# %% [markdown]
# #🧨 4. Catching Multiple Exceptions

# %%
try:
    a = int("ten")  # Causes ValueError
    b = 10 / 0      # Causes ZeroDivisionError
except (ValueError, ZeroDivisionError) as e:
    print("An error occurred:", e)
# Out:
# An error occurred: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# #🚫 5. Raising Custom Exceptions

# %%
# Raise your own error using 'raise'

def check_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative!")
    else:
        print("Age is valid.")

try:
    check_age(-5)
except ValueError as e:
    print("Caught an exception:", e)
# Out:
# Caught an exception: Age cannot be negative!

# %% [markdown]
# #🔍 6. DEBUGGING PRACTICES
#
# 🛠️ A. Using print() statements

# %%
def divide(a, b):
    print(f"Dividing {a} by {b}")  # Debug info
    return a / b

print(divide(10, 2))  # Correct
# print(divide(10, 0))  # Uncomment to see the crash
# Out:
# Dividing 10 by 2
# 5.0

# %% [markdown]
# #🛠️ B. Using traceback module (for detailed errors)

# %%
import traceback

try:
    result = 10 / 0
except Exception as e:
    print("Something went wrong.")
    traceback.print_exc()  # Prints detailed error stack
# Out:
# Something went wrong.
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1711/1155219331.py", line 4, in <cell line: 0>
#     result = 10 / 0
#              ~~~^~~
# ZeroDivisionError: division by zero

# %% [markdown]
# #🛠️ C. Using the Python Debugger (pdb)

# %%
# Uncomment to use the debugger
# import pdb

def calculate_total(price, quantity):
    # pdb.set_trace()  # Start interactive debugger here
    return price * quantity

print(calculate_total(50, 2))
# Out:
# 100

# %% [markdown]
# #📁 1. os – Operating System Interface

# %%
import os

# Get current working directory
print("Current Directory:", os.getcwd())

# List files and directories in current directory
print("Files and Folders:", os.listdir())

# Create a new folder
os.mkdir("demo_folder")  # Creates folder named 'demo_folder'

# Rename a folder
os.rename("demo_folder", "renamed_folder")

# Remove a folder (make sure it's empty)
os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']

# %% [markdown]
# #📆 2. datetime – Date and Time Handling

# %%
from datetime import datetime, date, timedelta

# Current date and time
now = datetime.now()
print("Now:", now)

# Only today's date
today = date.today()
print("Today's Date:", today)

# Create a specific date
dob = date(2000, 1, 1)
print("DOB:", dob)

# Date arithmetic
yesterday = today - timedelta(days=1)
tomorrow = today + timedelta(days=1)

print("Yesterday:", yesterday)
print("Tomorrow:", tomorrow)

# Format date to string
formatted = now.strftime("%d-%m-%Y %H:%M:%S")
print("Formatted DateTime:", formatted)
# Out:
# Now: 2026-07-20 08:05:56.136631
# Today's Date: 2026-07-20
# DOB: 2000-01-01
# Yesterday: 2026-07-19
# Tomorrow: 2026-07-21
# Formatted DateTime: 20-07-2026 08:05:56

# %% [markdown]
# #🎲 3. random – Random Numbers & Choices

# %%
import random

# Generate random integer between 1 and 100
print("Random Int:", random.randint(1, 100))

# Generate random float between 0 and 1
print("Random Float:", random.random())

# Choose a random item from a list
colors = ['red', 'green', 'blue']
print("Random Color:", random.choice(colors))

# Shuffle a list
random.shuffle(colors)
print("Shuffled List:", colors)

# Generate a random sample of multiple items
print("Sample:", random.sample(range(1, 50), 5))
# Out:
# Random Int: 71
# Random Float: 0.8015780133959631
# Random Color: green
# Shuffled List: ['green', 'blue', 'red']
# Sample: [27, 1, 42, 24, 32]

# %% [markdown]
# #📦 4. collections – Specialized Containers
# 🔹 A. Counter

# %%
from collections import Counter

# Count occurrences of elements in a list
fruits = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']
count = Counter(fruits)
print("Fruit Count:", count)
# Out:
# Fruit Count: Counter({'apple': 3, 'banana': 2, 'orange': 1})

# %% [markdown]
# 🔹 B. defaultdict

# %%
from collections import defaultdict

# Returns a default value for missing keys
marks = defaultdict(lambda: 0)
marks['Math'] = 90
marks['Science'] = 80
print("English Marks (not set):", marks['English'])  # Returns 0
# Out:
# English Marks (not set): 0

# %% [markdown]
# 🔹 C. namedtuple

# %%
from collections import namedtuple

# Create a Point object with x and y
Point = namedtuple('Point', 'x y')
p1 = Point(10, 20)
print("Point:", p1)
print("x:", p1.x, "y:", p1.y)
# Out:
# Point: Point(x=10, y=20)
# x: 10 y: 20

# %% [markdown]
# 🔹 D. deque

# %%
from collections import deque

# Double-ended queue
dq = deque([1, 2, 3])
dq.append(4)        # Add to right
dq.appendleft(0)    # Add to left
dq.pop()            # Remove from right
dq.popleft()        # Remove from left
print("Deque after operations:", dq)
# Out:
# Deque after operations: deque([1, 2, 3])

# %% [markdown]
# # --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
# print("\n--- Task 1: Data Generation and Basic Structures ---")
#
# # 1.1 Generate a list of 100 simulated sensor readings.
# #    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
# #    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
# #    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
# #    - device_type: Randomly chosen from DEVICE_TYPES.
# #    - location: Randomly chosen from LOCATIONS.
# #    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# # Store these in a list called 'raw_sensor_data'.
#
# # Your code for Task 1.1 here:
#
#
#
# ```
# `# This is formatted as code`
# ```

# %%
import random
from datetime import datetime, timedelta

# Example constants (use the ones provided in your assignment if already defined)
DEVICE_TYPES = ["Temperature", "Humidity", "Pressure"]
LOCATIONS = ["Lab A", "Lab B", "Warehouse"]

READING_RANGES = {
    "Temperature": (0, 50),
    "Humidity": (20, 90),
    "Pressure": (950, 1050)
}

# Generate a starting timestamp
start_time = datetime.now()

# Generate 100 simulated sensor readings
raw_sensor_data = []

for i in range(1, 101):
    timestamp = start_time + timedelta(seconds=i)

    device_id = f"DEV{i:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    reading = (
        timestamp.strftime("%Y-%m-%d %H:%M:%S"),
        device_id,
        device_type,
        location,
        value
    )

    raw_sensor_data.append(reading)

print(raw_sensor_data)
# Out:
# [('2026-07-20 08:54:09', 'DEV001', 'Temperature', 'Lab B', 23.52), ('2026-07-20 08:54:10', 'DEV002', 'Temperature', 'Lab B', 9.85), ('2026-07-20 08:54:11', 'DEV003', 'Humidity', 'Lab A', 53.54), ('2026-07-20 08:54:12', 'DEV004', 'Humidity', 'Lab A', 26.35), ('2026-07-20 08:54:13', 'DEV005', 'Temperature', 'Lab B', 1.48), ('2026-07-20 08:54:14', 'DEV006', 'Temperature', 'Warehouse', 43.4), ('2026-07-20 08:54:15', 'DEV007', 'Pressure', 'Lab B', 1027.75), ('2026-07-20 08:54:16', 'DEV008', 'Temperature', 'Lab A', 12.83), ('2026-07-20 08:54:17', 'DEV009', 'Humidity', 'Lab B', 48.7), ('2026-07-20 08:54:18', 'DEV010', 'Humidity', 'Lab A', 56.07), ('2026-07-20 08:54:19', 'DEV011', 'Pressure', 'Lab A', 953.84), ('2026-07-20 08:54:20', 'DEV012', 'Humidity', 'Lab A', 53.93), ('2026-07-20 08:54:21', 'DEV013', 'Pressure', 'Warehouse', 1048.61), ('2026-07-20 08:54:22', 'DEV014', 'Pressure', 'Lab A', 952.51), ('2026-07-20 08:54:23', 'DEV015', 'Pressure', 'Lab B', 1007.43), ('2026-07-20 08:54:24', 'DEV016', 'Temperature', 'Warehouse', 9.67), ('2026-07-20 08:54:25', 'DEV017', 'Pressure', 'Lab B', 986.25), ('2026-07-20 08:54:26', 'DEV018', 'Humidity', 'Warehouse', 21.58), ('2026-07-20 08:54:27', 'DEV019', 'Humidity', 'Lab A', 21.54), ('2026-07-20 08:54:28', 'DEV020', 'Pressure', 'Lab B', 1015.35), ('2026-07-20 08:54:29', 'DEV021', 'Temperature', 'Lab A', 33.27), ('2026-07-20 08:54:30', 'DEV022', 'Pressure', 'Warehouse', 1004.38), ('2026-07-20 08:54:31', 'DEV023', 'Temperature', 'Warehouse', 6.19), ('2026-07-20 08:54:32', 'DEV024', 'Temperature', 'Lab B', 0.14), ('2026-07-20 08:54:33', 'DEV025', 'Pressure', 'Lab B', 1012.96), ('2026-07-20 08:54:34', 'DEV026', 'Temperature', 'Lab A', 23.18), ('2026-07-20 08:54:35', 'DEV027', 'Humidity', 'Lab A', 72.04), ('2026-07-20 08:54:36', 'DEV028', 'Pressure', 'Lab B', 1032.6), ('2026-07-20 08:54:37', 'DEV029', 'Pressure', 'Lab A', 992.0), ('2026-07-20 08:54:38', 'DEV030', 'Humidity', 'Lab A', 89.2), ('2026-07-20 08:54:39', 'DEV031', 'Pressure', 'Lab B', 1026.66), ('2026-07-20 08:54:40', 'DEV032', 'Humidity', 'Lab B', 87.01), ('2026-07-20 08:54:41', 'DEV033', 'Temperature', 'Lab B', 26.86), ('2026-07-20 08:54:42', 'DEV034', 'Temperature', 'Lab B', 30.91), ('2026-07-20 08:54:43', 'DEV035', 'Humidity', 'Lab A', 27.62), ('2026-07-20 08:54:44', 'DEV036', 'Humidity', 'Lab A', 37.87), ('2026-07-20 08:54:45', 'DEV037', 'Temperature', 'Lab A', 24.39), ('2026-07-20 08:54:46', 'DEV038', 'Temperature', 'Warehouse', 30.54), ('2026-07-20 08:54:47', 'DEV039', 'Pressure', 'Warehouse', 978.68), ('2026-07-20 08:54:48', 'DEV040', 'Pressure', 'Warehouse', 1020.29), ('2026-07-20 08:54:49', 'DEV041', 'Pressure', 'Lab B', 1032.46), ('2026-07-20 08:54:50', 'DEV042', 'Humidity', 'Lab A', 73.85), ('2026-07-20 08:54:51', 'DEV043', 'Temperature', 'Lab A', 34.3), ('2026-07-20 08:54:52', 'DEV044', 'Humidity', 'Lab B', 77.08), ('2026-07-20 08:54:53', 'DEV045', 'Pressure', 'Lab A', 1030.62), ('2026-07-20 08:54:54', 'DEV046', 'Temperature', 'Lab B', 7.42), ('2026-07-20 08:54:55', 'DEV047', 'Temperature', 'Lab B', 34.47), ('2026-07-20 08:54:56', 'DEV048', 'Pressure', 'Lab A', 972.08), ('2026-07-20 08:54:57', 'DEV049', 'Temperature', 'Warehouse', 13.71), ('2026-07-20 08:54:58', 'DEV050', 'Humidity', 'Lab B', 56.65), ('2026-07-20 08:54:59', 'DEV051', 'Humidity', 'Warehouse', 77.33), ('2026-07-20 08:55:00', 'DEV052', 'Temperature', 'Lab A', 2.8), ('2026-07-20 08:55:01', 'DEV053', 'Humidity', 'Lab A', 67.56), ('2026-07-20 08:55:02', 'DEV054', 'Pressure', 'Lab A', 1022.68), ('2026-07-20 08:55:03', 'DEV055', 'Temperature', 'Warehouse', 49.99), ('2026-07-20 08:55:04', 'DEV056', 'Humidity', 'Lab A', 57.69), ('2026-07-20 08:55:05', 'DEV057', 'Temperature', 'Warehouse', 16.25), ('2026-07-20 08:55:06', 'DEV058', 'Humidity', 'Lab B', 26.87), ('2026-07-20 08:55:07', 'DEV059', 'Humidity', 'Warehouse', 57.87), ('2026-07-20 08:55:08', 'DEV060', 'Humidity', 'Lab A', 56.82), ('2026-07-20 08:55:09', 'DEV061', 'Pressure', 'Lab A', 1026.86), ('2026-07-20 08:55: ...

# %% [markdown]
# # 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
# #     where 'device_type' is 'Temperature_Sensor'.
# #     Each item in 'temperature_readings' should be a dictionary with keys:
# #     'timestamp', 'device_id', 'location', 'temperature_celsius'.
#
# # Your code for Task 1.2 here:

# %%
import datetime
import random

DEVICE_TYPES = [
    'Temperature_Sensor',
    'Humidity_Sensor',
    'Pressure_Sensor',
    'Light_Sensor'
]

LOCATIONS = [
    'Lab1',
    'Lab2',
    'OfficeA',
    'OfficeB',
    'Warehouse'
]

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

# Generate raw_sensor_data
raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(1, 101):
    timestamp = start_time + datetime.timedelta(seconds=i)

    device_id = f"DEV{i:03d}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    min_value, max_value = READING_RANGES[device_type]

    value = round(random.uniform(min_value, max_value), 2)

    reading = (
        timestamp.strftime('%Y-%m-%d %H:%M:%S'),
        device_id,
        device_type,
        location,
        value
    )

    raw_sensor_data.append(reading)


# Create temperature_readings
temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == 'Temperature_Sensor':
        temperature_readings.append({
            'timestamp': timestamp,
            'device_id': device_id,
            'location': location,
            'temperature_celsius': value
        })


# Print the output
print(temperature_readings)
# Out:
# [{'timestamp': '2026-07-20 09:09:44', 'device_id': 'DEV001', 'location': 'OfficeB', 'temperature_celsius': 29.06}, {'timestamp': '2026-07-20 09:09:46', 'device_id': 'DEV003', 'location': 'Lab1', 'temperature_celsius': 20.76}, {'timestamp': '2026-07-20 09:09:49', 'device_id': 'DEV006', 'location': 'Lab2', 'temperature_celsius': 27.44}, {'timestamp': '2026-07-20 09:09:58', 'device_id': 'DEV015', 'location': 'Lab2', 'temperature_celsius': 23.24}, {'timestamp': '2026-07-20 09:09:59', 'device_id': 'DEV016', 'location': 'Warehouse', 'temperature_celsius': 26.7}, {'timestamp': '2026-07-20 09:10:01', 'device_id': 'DEV018', 'location': 'Lab2', 'temperature_celsius': 26.25}, {'timestamp': '2026-07-20 09:10:02', 'device_id': 'DEV019', 'location': 'Lab2', 'temperature_celsius': 22.75}, {'timestamp': '2026-07-20 09:10:05', 'device_id': 'DEV022', 'location': 'OfficeB', 'temperature_celsius': 21.41}, {'timestamp': '2026-07-20 09:10:06', 'device_id': 'DEV023', 'location': 'Warehouse', 'temperature_celsius': 18.19}, {'timestamp': '2026-07-20 09:10:08', 'device_id': 'DEV025', 'location': 'OfficeB', 'temperature_celsius': 21.19}, {'timestamp': '2026-07-20 09:10:14', 'device_id': 'DEV031', 'location': 'OfficeB', 'temperature_celsius': 29.57}, {'timestamp': '2026-07-20 09:10:17', 'device_id': 'DEV034', 'location': 'OfficeB', 'temperature_celsius': 24.35}, {'timestamp': '2026-07-20 09:10:19', 'device_id': 'DEV036', 'location': 'Lab1', 'temperature_celsius': 18.35}, {'timestamp': '2026-07-20 09:10:24', 'device_id': 'DEV041', 'location': 'Warehouse', 'temperature_celsius': 24.08}, {'timestamp': '2026-07-20 09:10:25', 'device_id': 'DEV042', 'location': 'Warehouse', 'temperature_celsius': 20.05}, {'timestamp': '2026-07-20 09:10:34', 'device_id': 'DEV051', 'location': 'OfficeA', 'temperature_celsius': 19.97}, {'timestamp': '2026-07-20 09:10:35', 'device_id': 'DEV052', 'location': 'Warehouse', 'temperature_celsius': 19.44}, {'timestamp': '2026-07-20 09:10:36', 'device_id': 'DEV053', 'location': 'OfficeB', 'temperature_celsius': 22.36}, {'timestamp': '2026-07-20 09:10:37', 'device_id': 'DEV054', 'location': 'Lab1', 'temperature_celsius': 22.14}, {'timestamp': '2026-07-20 09:10:39', 'device_id': 'DEV056', 'location': 'OfficeA', 'temperature_celsius': 27.47}, {'timestamp': '2026-07-20 09:10:44', 'device_id': 'DEV061', 'location': 'OfficeA', 'temperature_celsius': 22.08}, {'timestamp': '2026-07-20 09:10:46', 'device_id': 'DEV063', 'location': 'OfficeA', 'temperature_celsius': 22.36}, {'timestamp': '2026-07-20 09:10:49', 'device_id': 'DEV066', 'location': 'Lab1', 'temperature_celsius': 22.03}, {'timestamp': '2026-07-20 09:11:00', 'device_id': 'DEV077', 'location': 'OfficeA', 'temperature_celsius': 24.61}, {'timestamp': '2026-07-20 09:11:03', 'device_id': 'DEV080', 'location': 'Lab2', 'temperature_celsius': 23.41}, {'timestamp': '2026-07-20 09:11:07', 'device_id': 'DEV084', 'location': 'Lab2', 'temperature_celsius': 19.01}, {'timestamp': '2026-07-20 09:11:08', 'device_id': 'DEV085', 'location': 'Lab1', 'temperature_celsius': 20.48}, {'timestamp': '2026-07-20 09:11:13', 'device_id': 'DEV090', 'location': 'Lab1', 'temperature_celsius': 28.2}, {'timestamp': '2026-07-20 09:11:19', 'device_id': 'DEV096', 'location': 'OfficeB', 'temperature_celsius': 20.71}, {'timestamp': '2026-07-20 09:11:20', 'device_id': 'DEV097', 'location': 'OfficeB', 'temperature_celsius': 25.21}, {'timestamp': '2026-07-20 09:11:21', 'device_id': 'DEV098', 'location': 'Lab1', 'temperature_celsius': 21.96}]

# %% [markdown]
# # 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.
#
# # Your code for Task 1.3 here:

# %%
unique_locations = set()

for reading in raw_sensor_data:
    location = reading[3]
    unique_locations.add(location)

print(unique_locations)
# Out:
# {'Warehouse', 'Lab A', 'Lab B'}

# %% [markdown]
# # 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
# #     a tuple: (min_value, max_value) observed for that device type across all readings.
# #     Initialize with sensible large/small values.
#
# # Your code for Task 1.4 here:

# %%
device_stats = {}

for device_type in DEVICE_TYPES:

    min_value = float('inf')
    max_value = float('-inf')

    for reading in raw_sensor_data:

        if reading[2] == device_type:

            value = reading[4]

            if value < min_value:
                min_value = value

            if value > max_value:
                max_value = value

    device_stats[device_type] = (min_value, max_value)

print(device_stats)
# Out:
# {'Temperature_Sensor': (18.19, 29.57), 'Humidity_Sensor': (34.3, 79.61), 'Pressure_Sensor': (980.23, 1027.14), 'Light_Sensor': (130.24, 955.28)}

# %% [markdown]
# # 1.5: Advanced Indexing and Slicing (Lists and Strings)
# print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")
#
# # Let's use 'raw_sensor_data' and create a sample string for these tasks.
# sample_string = "PythonProgrammingIsFun"
#
# # 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
# #       Store the result in 'sliced_readings_1'.
# #       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
# #       Store the result in 'sliced_readings_2'.
#
# # Your code for Task 1.5.1 here:

# %%
# Extract the 10th to the 20th readings (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_1)
print(sliced_readings_2)
# Out:
# [('2026-07-20 09:09:53', 'DEV010', 'Humidity_Sensor', 'OfficeB', 65.87), ('2026-07-20 09:09:54', 'DEV011', 'Pressure_Sensor', 'OfficeA', 1023.03), ('2026-07-20 09:09:55', 'DEV012', 'Light_Sensor', 'OfficeB', 682.05), ('2026-07-20 09:09:56', 'DEV013', 'Light_Sensor', 'OfficeB', 579.61), ('2026-07-20 09:09:57', 'DEV014', 'Humidity_Sensor', 'OfficeA', 66.43), ('2026-07-20 09:09:58', 'DEV015', 'Temperature_Sensor', 'Lab2', 23.24), ('2026-07-20 09:09:59', 'DEV016', 'Temperature_Sensor', 'Warehouse', 26.7), ('2026-07-20 09:10:00', 'DEV017', 'Light_Sensor', 'Warehouse', 955.28), ('2026-07-20 09:10:01', 'DEV018', 'Temperature_Sensor', 'Lab2', 26.25), ('2026-07-20 09:10:02', 'DEV019', 'Temperature_Sensor', 'Lab2', 22.75), ('2026-07-20 09:10:03', 'DEV020', 'Humidity_Sensor', 'OfficeB', 76.58)]
# [('2026-07-20 09:09:44', 'DEV001', 'Temperature_Sensor', 'OfficeB', 29.06), ('2026-07-20 09:09:49', 'DEV006', 'Temperature_Sensor', 'Lab2', 27.44), ('2026-07-20 09:09:54', 'DEV011', 'Pressure_Sensor', 'OfficeA', 1023.03), ('2026-07-20 09:09:59', 'DEV016', 'Temperature_Sensor', 'Warehouse', 26.7), ('2026-07-20 09:10:04', 'DEV021', 'Pressure_Sensor', 'OfficeB', 1027.14), ('2026-07-20 09:10:09', 'DEV026', 'Humidity_Sensor', 'Lab2', 43.35), ('2026-07-20 09:10:14', 'DEV031', 'Temperature_Sensor', 'OfficeB', 29.57), ('2026-07-20 09:10:19', 'DEV036', 'Temperature_Sensor', 'Lab1', 18.35), ('2026-07-20 09:10:24', 'DEV041', 'Temperature_Sensor', 'Warehouse', 24.08), ('2026-07-20 09:10:29', 'DEV046', 'Humidity_Sensor', 'OfficeA', 48.98), ('2026-07-20 09:10:34', 'DEV051', 'Temperature_Sensor', 'OfficeA', 19.97), ('2026-07-20 09:10:39', 'DEV056', 'Temperature_Sensor', 'OfficeA', 27.47), ('2026-07-20 09:10:44', 'DEV061', 'Temperature_Sensor', 'OfficeA', 22.08), ('2026-07-20 09:10:49', 'DEV066', 'Temperature_Sensor', 'Lab1', 22.03), ('2026-07-20 09:10:54', 'DEV071', 'Humidity_Sensor', 'Lab2', 56.54), ('2026-07-20 09:10:59', 'DEV076', 'Humidity_Sensor', 'Warehouse', 73.9), ('2026-07-20 09:11:04', 'DEV081', 'Light_Sensor', 'Warehouse', 804.36), ('2026-07-20 09:11:09', 'DEV086', 'Pressure_Sensor', 'Warehouse', 982.48), ('2026-07-20 09:11:14', 'DEV091', 'Humidity_Sensor', 'Warehouse', 66.66), ('2026-07-20 09:11:19', 'DEV096', 'Temperature_Sensor', 'OfficeB', 20.71)]

# %% [markdown]
# # 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
# #       Store the result in 'substring_1'.
# #       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
# #       Store the result in 'substring_2'.
#
# # Your code for Task 1.5.2 here:

# %%
# Define the string first
sample_string = "PythonProgrammingIsFun"

# Extract "Programming"
substring_1 = sample_string[6:17]

# Reverse "Python"
substring_2 = sample_string[5::-1]

print(substring_1)
print(substring_2)
# Out:
# Programming
# nohtyP

# %% [markdown]
# # 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
# #       Store it in 'fifth_reading_device_type'.
# #       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
# #       Store it in 'device_type_suffix'.
#
# # Your code for Task 1.5.3 here:

# %%
# Get the device_type from the 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Get the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

print(fifth_reading_device_type)
print(device_type_suffix)
# Out:
# Pressure_Sensor
# Sensor

# %% [markdown]
# # --- Task 2: Writing and Using Functions in Python ---
# print("\n--- Task 2: Function Definitions and Usage ---")
#
# # 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
# #     that takes the 'raw_sensor_data' list and a 'target_location' string.
# #     It should return a list of all readings (as tuples) for that specific location.
#
# # Your code for Task 2.1 here:

# %%
def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result


# Call the function
lab1_readings = get_readings_by_location(raw_sensor_data, 'Lab1')

# Print the output
print("\nReadings from Lab1:")
print(lab1_readings)
# Out:
# Readings from Lab1:
# [('2026-07-20 09:09:46', 'DEV003', 'Temperature_Sensor', 'Lab1', 20.76), ('2026-07-20 09:10:18', 'DEV035', 'Light_Sensor', 'Lab1', 303.51), ('2026-07-20 09:10:19', 'DEV036', 'Temperature_Sensor', 'Lab1', 18.35), ('2026-07-20 09:10:31', 'DEV048', 'Humidity_Sensor', 'Lab1', 66.93), ('2026-07-20 09:10:37', 'DEV054', 'Temperature_Sensor', 'Lab1', 22.14), ('2026-07-20 09:10:38', 'DEV055', 'Humidity_Sensor', 'Lab1', 76.12), ('2026-07-20 09:10:49', 'DEV066', 'Temperature_Sensor', 'Lab1', 22.03), ('2026-07-20 09:10:55', 'DEV072', 'Pressure_Sensor', 'Lab1', 992.87), ('2026-07-20 09:11:08', 'DEV085', 'Temperature_Sensor', 'Lab1', 20.48), ('2026-07-20 09:11:12', 'DEV089', 'Pressure_Sensor', 'Lab1', 1022.4), ('2026-07-20 09:11:13', 'DEV090', 'Temperature_Sensor', 'Lab1', 28.2), ('2026-07-20 09:11:17', 'DEV094', 'Humidity_Sensor', 'Lab1', 62.48), ('2026-07-20 09:11:21', 'DEV098', 'Temperature_Sensor', 'Lab1', 21.96), ('2026-07-20 09:11:23', 'DEV100', 'Pressure_Sensor', 'Lab1', 989.6)]

# %% [markdown]
# # 2.2 Write a function `calculate_average_temperature(temp_data_list)`
# #     that takes the 'temperature_readings' list (list of dictionaries).
# #     It should calculate and return the average temperature. Return 0.0 if the list is empty.
#
# # Your code for Task 2.2 here:

# %%
def calculate_average_temperature(temp_data_list):

    if len(temp_data_list) == 0:
        return 0.0

    total_temperature = 0

    for reading in temp_data_list:
        total_temperature += reading['temperature_celsius']

    average_temperature = total_temperature / len(temp_data_list)

    return average_temperature


# Call the function
average_temperature = calculate_average_temperature(
    temperature_readings
)

# Print the output
print("\nAverage Temperature:")
print(round(average_temperature, 2))
# Out:
# Average Temperature:
# 23.06

# %% [markdown]
# # 2.3 Write a function `generate_report_line(reading_dict)`
# #     that takes a single temperature reading dictionary.
# #     It should return a formatted string like:
# #     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"
#
# # Your code for Task 2.3 here:

# %%
def generate_report_line(reading_dict):

    report_line = (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )

    return report_line


# Test the function using the first temperature reading
if len(temperature_readings) > 0:

    report_line = generate_report_line(
        temperature_readings[0]
    )

    print("\nGenerated Report Line:")
    print(report_line)

else:
    print("\nNo temperature readings available.")
# Out:
# Generated Report Line:
# [2026-07-20 09:09:44] Device DEV001 at OfficeB: 29.06°C

# %% [markdown]
# # --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
# print("\n--- Task 3: Core Library Usage ---")
#
# # 3.1 Use the `os` module to create a new directory named 'sensor_reports'
# #     in the current working directory, if it doesn't already exist.
#
# # Your code for Task 3.1 here:
# reports_dir = 'sensor_reports'
# if not os.path.exists(reports_dir):
#     os.makedirs(reports_dir)
#     print(f"\nDirectory '{reports_dir}' created.")
# else:
#     print(f"\nDirectory '{reports_dir}' already exists.")

# %%
reports_dir = 'sensor_reports'

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# Directory 'sensor_reports' created.

# %% [markdown]
# # 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
# #     Convert string timestamps to datetime objects first.
# #     Print the duration in days, hours, and minutes.
#
# # Your code for Task 3.2 here:

# %%
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 0 hours, 1 minutes.

# %% [markdown]
# # 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
# #     using the `random` module. Store it in 'random_values'.
#
# # Your code for Task 3.3 here:

# %%
random_values = []

for i in range(5):
    value = random.randint(100, 200)
    random_values.append(value)

print("\nRandom values:")
print(random_values)
# Out:
# Random values:
# [127, 142, 109, 195, 110]

# %% [markdown]
# # --- Task 4: File Handling in Python ---
# print("\n--- Task 4: File I/O ---")
#
# # 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
# #     Each line in the file should be generated using the `generate_report_line` function.
#
# # Your code for Task 4.1 here:

# %%
report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")
# Out:
# Temperature report written to 'sensor_reports/temperature_report.txt'.

# %% [markdown]
# # 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
# #     named 'read_report_lines'. Print the first 3 lines.
#
# # Your code for Task 4.2 here:
#
#
#
#
#
# print("\n--- Exercise Complete! ---")
# print("Great job completing the intermediate Python exercise.")
# print("Review your code and outputs to ensure correctness and understanding of all concepts.")
# print("Consider adding more complex scenarios or user inputs for further practice.")

# %%
# Read the report file
read_report_lines = []

try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()

    print("\nFirst 3 lines of the report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"\nError reading file '{report_filename}': {e}")


print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# First 3 lines of the report:
# [2026-07-20 09:09:44] Device DEV001 at OfficeB: 29.06°C
# [2026-07-20 09:09:46] Device DEV003 at Lab1: 20.76°C
# [2026-07-20 09:09:49] Device DEV006 at Lab2: 27.44°C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
